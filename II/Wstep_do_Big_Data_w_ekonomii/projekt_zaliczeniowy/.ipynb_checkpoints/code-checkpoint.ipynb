# %% [markdown]
# TODO: Oszacować pojemność ośrodków pomocy społecznej

# %%
import pandas as pd
import json
import requests
import numpy as np
import matplotlib.pyplot as plt

# %%
struktura_ludnosci = pd.ExcelFile('struktura_ludnosci.xls')
struktura_ludnosci = struktura_ludnosci.parse(0)
struktura_ludnosci = struktura_ludnosci.drop([0, 1, 2, 4])
struktura_ludnosci = struktura_ludnosci.transpose()
struktura_ludnosci = struktura_ludnosci.reset_index()
struktura_ludnosci = struktura_ludnosci.drop(columns=['index'])
struktura_ludnosci.columns = struktura_ludnosci.iloc[0]
struktura_ludnosci.drop(index=0, inplace=True)
struktura_ludnosci = struktura_ludnosci.set_index('Grupy wieku')
struktura_ludnosci.index.names = ['Rok']
struktura_ludnosci.index = struktura_ludnosci.index.astype(np.int64)
struktura_ludnosci = struktura_ludnosci.loc[:, :'Kobiety w wieku rozrodczym 15 - 49 lat          ']
struktura_ludnosci.rename(columns=lambda x: str(x).strip(), inplace=True)

# %%
struktura_ludnosci.columns
# Out:
# Index(['OGÓŁEM', '0 - 2 lata', '3 -6', '7 - 14', '15 - 18', 'w tym: 18',
#        '19 - 24', '0 - 17', '18 -59/64', 'w tym:', '18 - 44', '45 - 59/64',
#        '60/65 lat i więcej', '0 - 14', '15 - 64', '65 lat i więcej',
#        'Kobiety w wieku rozrodczym 15 - 49 lat'],
#       dtype='object', name=0)

# %%
plot_data = struktura_ludnosci.loc[:, ['45 - 59/64', '65 lat i więcej']]
fig, ax = plt.subplots()
ax.set_title('Stan i struktura ludności w wieku 45-65+ w latach 1986 - 2016')
for column in plot_data.columns:
    ax.plot(plot_data.index, plot_data[column])
plt.legend(plot_data.columns)
ax.set_xlabel('Rok')
ax.set_ylabel('Liczba ludności (w tys.)')
plt.show()
fig.savefig('struktura_ludnosci.jpg')

# %% [markdown]
# Możemy jednocześnie zasymulować stan demograficzny w przyszłości, przesuwając niższe grupy wiekowe w czasie, aby wyestymować liczbę ludności potrzebującej opieki specjalistycznej w kolejnych latach

# %%
struktura_zmiany = pd.ExcelFile('zmiany_w_strukturze_ludnosci.xls')

# %%
struktura_zmiany.parse(0)
# Out:
#    Tabl. 3.  Rozwój i zmiany w strukturze ludności w latach 1950-2016  \
# 0                                              OGÓŁEM
# 1                                                 NaN
# 2                                               Lata
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 72                                               2016
# 73                                                NaN
# 74        a) 18-59 lat (kobiety)/64 lata (mężczyźni),
# 75                                     b)  0-17 lat,
# 76   c)  60 lat i więcej (kobiety)/65 lat i więcej...
#
#                              Unnamed: 1                          Unnamed: 2  \
# 0                                   NaN                                 NaN
# 1                                   NaN                                 NaN
# ...
